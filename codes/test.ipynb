# %%
from experience_state import JailbreakState

# %%
state = JailbreakState(
            pre_query="",
            full_query="",
            response="",
            harmfulness_score=1,
            mutation=["mutation"],
            method="",
            success_times=1,
            false_times=0
        )

# %%
list1
# Out:
# [{
#    "mutation": [
#      "mutation"
#    ],
#    "full_query": "",
#    "pre_query": "",
#    "response": "",
#    "harmfulness_score": 1,
#    "method": "",
#    "success_times": 1,
#    "false_times": 0
#  },
#  {
#    "mutation": [
#      "mutation"
#    ],
#    "full_query": "",
#    "pre_query": "",
#    "response": "",
#    "harmfulness_score": 1,
#    "method": "",
#    "success_times": 1,
#    "false_times": 0
#  },
#  {
#    "mutation": [
#      "mutation"
#    ],
#    "full_query": "",
#    "pre_query": "",
#    "response": "",
#    "harmfulness_score": 1,
#    "method": "",
#    "success_times": 1,
#    "false_times": 0
#  },
#  {
#    "mutation": [
#      "mutation"
#    ],
#    "full_query": "",
#    "pre_query": "",
#    "response": "",
#    "harmfulness_score": 1,
#    "method": "",
#    "success_times": 1,
#    "false_times": 0
#  },
#  {
#    "mutation": [
#      "mutation"
#    ],
#    "full_query": "",
#    "pre_query": "",
#    "response": "",
# ...
